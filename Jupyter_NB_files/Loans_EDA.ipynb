# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
loans_df = pd.read_csv('LoanStats_2017Q1 2.csv')
loans_df
# Out:
# C:\Users\jwag2\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (112) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     NaN        NaN       3600         3600             3600   36 months
# 1     NaN        NaN      15000        15000            15000   60 months
# 2     NaN        NaN       8400         8400             8400   36 months
# 3     NaN        NaN       4000         4000             4000   36 months
# 4     NaN        NaN       6000         6000             6000   36 months
# ...    ..        ...        ...          ...              ...         ...
# 96774 NaN        NaN      30000        30000            30000   60 months
# 96775 NaN        NaN      15000        15000            15000   36 months
# ...

# %%
print(loans_df.dtypes)
# Out:
# id                                     float64
# member_id                              float64
# loan_amnt                                int64
# funded_amnt                              int64
# funded_amnt_inv                          int64
#                                         ...
# sec_app_open_il_6m                     float64
# sec_app_num_rev_accts                  float64
# sec_app_chargeoff_within_12_mths       float64
# sec_app_collections_12_mths_ex_med     float64
# sec_app_mths_since_last_major_derog    float64
# Length: 122, dtype: object

# %%
loans_df.describe()
# Out:
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  96779.000000  96779.000000     96779.000000
# mean   NaN        NaN  14858.279947  14858.279947     14853.928022
# std    NaN        NaN   9396.273231   9396.273231      9393.128515
# min    NaN        NaN   1000.000000   1000.000000      1000.000000
# 25%    NaN        NaN   7800.000000   7800.000000      7800.000000
# 50%    NaN        NaN  12000.000000  12000.000000     12000.000000
# 75%    NaN        NaN  20000.000000  20000.000000     20000.000000
# max    NaN        NaN  40000.000000  40000.000000     40000.000000
#
#         installment    annual_inc  url  desc           dti  ...  \
# count  96779.000000  9.677900e+04  0.0   0.0  96779.000000  ...
# mean     450.885696  8.276104e+04  NaN   NaN     22.107865  ...
# std      283.501239  2.149442e+05  NaN   NaN    185.235747  ...
# min       30.120000  0.000000e+00  NaN   NaN     -1.000000  ...
# ...

# %%
loans_df.isnull().sum()
# Out:
# id                                     96779
# member_id                              96779
# loan_amnt                                  0
# funded_amnt                                0
# funded_amnt_inv                            0
#                                        ...
# sec_app_open_il_6m                     95754
# sec_app_num_rev_accts                  95754
# sec_app_chargeoff_within_12_mths       95754
# sec_app_collections_12_mths_ex_med     95754
# sec_app_mths_since_last_major_derog    96423
# Length: 122, dtype: int64

# %%
loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96779 entries, 0 to 96778
# Columns: 122 entries, id to sec_app_mths_since_last_major_derog
# dtypes: float64(43), int64(55), object(24)
# memory usage: 90.1+ MB

# %%
loans_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_il_6m', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog'],
#       dtype='object', length=122)

# %%
loans_df.shape
# Out:
# (96779, 122)
